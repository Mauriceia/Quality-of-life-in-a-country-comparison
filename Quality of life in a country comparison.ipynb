# %% [markdown]
#     To get the total Quality of life in 137 countries, it was used 7 subjects such as stability, rights, health, safety, climate, costs and population. Each of these subjets were breaking down in different %, as a final result Astralia would be the country with best total life's quality with 76% of the total. On the other hand, Congo would be the country with least life's quality.
#         Let's try to understand it better:

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib 
import rcParams
import sqlalchemy

# %%
df = pd.read_csv('Quality_of_lifein_a_country_comparison.csv')

# %%
df
# Out:
#      Unnamed: 0  Rank                Country  Stability(15%)  Rights(20%)  \
# 0             0     1              Australia              86           92
# 1             1     2             San Marino              81           82
# 2             2     3              Hong Kong              77           85
# 3             3     4            Switzerland              91           99
# 4             4     5                  Macao              90           71
# ..          ...   ...                    ...             ...          ...
# 132         132   133               Cameroon              40           19
# 133         133   134                Nigeria              18           24
# 134         134   135                   Chad              46           12
# 135         135   136                  Sudan               8           11
# 136         136   137  Congo (Dem. Republic)              32            7
#
#      Health(15%)  Safety(10%)  Climate(15%)  Costs(15%)  Popularity(10%)  \
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
# gives the datatype/ column name/ missing data
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Rank                        137 non-null    int64
#  1   Country                     137 non-null    object
#  2   Stability(15%)              137 non-null    int64
#  3   Rights(20%)                 137 non-null    int64
#  4   Health(15%)                 137 non-null    int64
#  5   Safety(10%)                 137 non-null    int64
#  6   Climate(15%)                137 non-null    int64
#  7   Costs(15%)                  137 non-null    int64
#  8   Popularity(10%)             137 non-null    int64
#  9   TotalQuality of life(100%)  137 non-null    int64
# dtypes: int64(9), object(1)
# memory usage: 10.8+ KB
# None

# %%
# number of rows and columns
df.shape
# Out:
# (137, 10)

# %%
# There is no unnecessary spaces between words
df.columns
# Out:
# Index(['Rank', 'Country', 'Stability(15%)', 'Rights(20%)', 'Health(15%)',
#        'Safety(10%)', 'Climate(15%)', 'Costs(15%)', 'Popularity(10%)',
#        'TotalQuality of life(100%)'],
#       dtype='object')

# %%
# There is no country showing more than once
pd.set_option("display.max_rows", None)
df['Country'].value_counts()
# Out:
# Australia                 1
# Russia                    1
# Egypt                     1
# Brazil                    1
# Dominican Republic        1
# Jamaica                   1
# Madagascar                1
# Tanzania                  1
# Ghana                     1
# Bosnia and Herzegovina    1
# Nepal                     1
# Malawi                    1
# Kenya                     1
# Suriname                  1
# Laos                      1
# Colombia                  1
# Ukraine                   1
# Timor-Leste               1
# Trinidad and Tobago       1
# Moldova                   1
# Bolivia                   1
# Indonesia                 1
# Vietnam                   1
# Kazakhstan                1
# Mexico                    1
# Algeria                   1
# India                     1
# South Africa              1
# Rwanda                    1
# Senegal                   1
# Serbia                    1
# Turkey                    1
# Jordan                    1
# ...

# %%
#  df.loc[df['Country'] == 'Brazil']

# %%
# df.loc[df['Country'] == 'United States']

# %%
# df.loc[df['Country'] == 'Norway']

# %%
# Three countries got total % related to Safety 
df.loc[df['Safety(10%)'] == 100]
# Out:
#    Rank     Country  Stability(15%)  Rights(20%)  Health(15%)  Safety(10%)  \
# 0     1   Australia              86           92           87          100
# 6     7  Luxembourg              93           99           85          100
# 8     9   Singapore              83           89           79          100
#
#    Climate(15%)  Costs(15%)  Popularity(10%)  TotalQuality of life(100%)
# 0            90          23               41                          76
# 6            25          46               42                          71
# 8            45          55               39                          71

# %%
# Safety

plt.figure(figsize=(17,10))
sns.histplot(data=df, x= 'Safety(10%)', bins=137)
# Out:
# <AxesSubplot:xlabel='Safety(10%)', ylabel='Count'>

# %%
df = df.sort_values(by = ['Safety(10%)'], ascending = False)

# %%
plt.figure(figsize=(20,26))
plt.rc('font', size=11)
sns.barplot(x = 'Safety(10%)', y = 'Country', capsize = 0.3, data = df)
# plt.xticks(rotation=90)

plt.show()

# new_df = df.loc[(df['Safety(10%)', 'Health(15%)']) 

# new_df['Safety(10%)'].plot(kind = 'hist')
# plt.show()

# %%
df = df.sort_values(by = ['Costs(15%)'], ascending = False)
plt.figure(figsize=(20,26))
plt.rc('font', size=11)
sns.barplot(x = 'Costs(15%)', y = 'Country', capsize = 0.3, data = df)
# plt.xticks(rotation=90)

plt.show()

# %%
# The highest total life quality out of 100% is Australia with 75% of the total
df.loc[df['TotalQuality of life(100%)'] >= 75]
# Out:
#    Rank    Country  Stability(15%)  Rights(20%)  Health(15%)  Safety(10%)  \
# 0     1  Australia              86           92           87          100
#
#    Climate(15%)  Costs(15%)  Popularity(10%)  TotalQuality of life(100%)
# 0            90          23               41                          76

# %%
# The lowest total life quality out of 100% is in Congo with 29% of the total
df.loc[df['TotalQuality of life(100%)'] <= 30]
# Out:
#      Rank                Country  Stability(15%)  Rights(20%)  Health(15%)  \
# 135   136                  Sudan               8           11           18
# 136   137  Congo (Dem. Republic)              32            7            6
#
#      Safety(10%)  Climate(15%)  Costs(15%)  Popularity(10%)  \
# 135           55            40          66               24
# 136           10            54          60               36
#
#      TotalQuality of life(100%)
# 135                          30
# 136                          29

# %% [markdown]
#     Monzambique got the lowest rank related safety in it country. However, after analize the other subjects, Sudan and Congo are the 2 countries with the least total of quality of life, having the difference of only 1% between them.

# %%
#  Monzambique got the lowest safety rank 
df.loc[df['Safety(10%)'] <= 5]
# Out:
#      Rank     Country  Stability(15%)  Rights(20%)  Health(15%)  Safety(10%)  \
# 129   130  Mozambique              36           26           10            4
#
#      Climate(15%)  Costs(15%)  Popularity(10%)  TotalQuality of life(100%)
# 129            80          53               36                          36

# %%
# The lowest total life quality out of 100% is in Congo with 29% of the total
df.loc[df['TotalQuality of life(100%)'] <= 30]
# Out:
#      Rank                Country  Stability(15%)  Rights(20%)  Health(15%)  \
# 135   136                  Sudan               8           11           18
# 136   137  Congo (Dem. Republic)              32            7            6
#
#      Safety(10%)  Climate(15%)  Costs(15%)  Popularity(10%)  \
# 135           55            40          66               24
# 136           10            54          60               36
#
#      TotalQuality of life(100%)
# 135                          30
# 136                          29

# %%
# get the cost
# does cost affect in life quality

# %%
df.loc[df['Rights(20%)'] <= 10]
# Out:
#      Rank                Country  Stability(15%)  Rights(20%)  Health(15%)  \
# 130   131            Afghanistan              28            9           20
# 136   137  Congo (Dem. Republic)              32            7            6
#
#      Safety(10%)  Climate(15%)  Costs(15%)  Popularity(10%)  \
# 130           19            58          63               63
# 136           10            54          60               36
#
#      TotalQuality of life(100%)
# 130                          35
# 136                          29

# %%
df.loc[df['Country'] == 'United Kingdom']
# Out:
#     TotalQuality of life(100%)  Rank         Country  Stability(15%)  \
# 42                          61    43  United Kingdom              76
#
#     Rights(20%)  Health(15%)  Safety(10%)  Climate(15%)  Costs(15%)  \
# 42           91           78           95             6          34
#
#     Popularity(10%)
# 42               42

# %%
first_col = df.pop('TotalQuality of life(100%)')

# %%
df.insert(0, 'TotalQuality of life(100%)', first_col)

# %%
df.head()
# Out:
#     TotalQuality of life(100%)  Rank      Country  Stability(15%)  \
# 0                           76     1    Australia              86
# 6                           71     7   Luxembourg              93
# 8                           71     9    Singapore              83
# 3                           74     4  Switzerland              91
# 15                          69    16       Norway              89
#
#     Rights(20%)  Health(15%)  Safety(10%)  Climate(15%)  Costs(15%)  \
# 0            92           87          100            90          23
# 6            99           85          100            25          46
# 8            89           79          100            45          55
# 3            99           93           99            34          44
# 15           99           90           99            16          42
#
#     Popularity(10%)
# 0                41
# 6                42
# 8                39
# 3                46
# 15               37

# %%
df.corr()
# Out:
#                             TotalQuality of life(100%)      Rank  \
# TotalQuality of life(100%)                    1.000000 -0.989193
# Rank                                         -0.989193  1.000000
# Stability(15%)                                0.858164 -0.854773
# Rights(20%)                                   0.895649 -0.898624
# Health(15%)                                   0.861517 -0.860273
# Safety(10%)                                   0.763213 -0.745916
# Climate(15%)                                 -0.260525  0.290288
# Costs(15%)                                   -0.356321  0.348676
# Popularity(10%)                               0.192992 -0.194295
#
#                             Stability(15%)  Rights(20%)  Health(15%)  \
# TotalQuality of life(100%)        0.858164     0.895649     0.861517
# Rank                             -0.854773    -0.898624    -0.860273
# Stability(15%)                    1.000000     0.846775     0.693995
# ...

# %%
# get correlation
rcParams['figure.figsize'] = 50, 30
plt.rc('font', size=30)
heatmap = sns.heatmap(df.corr(), cmap = 'seismic', annot = True, vmin=-1, vmax=1);
plt.savefig('heatmap')

# %%
sns.pairplot(df);
